# %% [markdown]
# # Learning from Bullying Traces in Social Media

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv',names=['tweet_id','user_id','bullying_traces','type','form','teasing','author_role','emotion'])

# %%
data.columns
# Out:
# Index(['tweet_id', 'user_id', 'bullying_traces', 'type', 'form', 'teasing',
#        'author_role', 'emotion'],
#       dtype='object')

# %%
data
# Out:
#                 tweet_id    user_id bullying_traces             type   form  \
# 0     105730486382497793  322329899               y  self-disclosure  other
# 1     107688644067856384  185389094               y  self-disclosure  other
# 2     108654820042354688  361869056               n              NaN    NaN
# 3     102206417217392640  226320672               n              NaN    NaN
# 4     102779484725448704  297557032               n              NaN    NaN
# ...                  ...        ...             ...              ...    ...
# 7316   99912247060611074  162589166               y  self-disclosure  other
# 7317   99878062220517376  221054960               y       accusation  other
# 7318  100049839949221889  110032215               n              NaN    NaN
# 7319  100006640492875776  171842492               y           denial  other
# 7320   99712633174888448  225505498               y           report  other
#
#      teasing author_role  emotion
# 0          n      victim     none
# 1          n    defender  empathy
# 2        NaN         NaN      NaN
# 3        NaN         NaN      NaN
# 4        NaN         NaN      NaN
# ...      ...         ...      ...
# 7316       n    defender  empathy
# 7317       n     accuser     none
# 7318     NaN         NaN      NaN
# 7319       n       bully     none
# 7320       n    reporter     none
#
# [7321 rows x 8 columns]

# %% [markdown]
# ### Attribute values
#
# Bullying_Traces:
#
#     y (bullying trace)
#     n (not a bullying trace)
#
# Type:
#
#     accusation
#     cyberbullying
#     denial
#     report
#     self-disclosure
#     NA - The tweet is not a bullying trace and we didn't annotate its type
#
# Form:
#
#     cyberbullying
#     other
#     physical
#     property damage
#     relational
#     verbal
#     NA - The tweet is not a bullying trace and we didn't annotate its form
# Teasing:
#
#     y - Teasing
#     n - Not teasing
#     NA - The tweet is not a bullying trace and we didn't annotate if it is teasing
# Author_Role:
#
#     accuser
#     assistant
#     bully
#     defender
#     reinforcer
#     reporter
#     victim
#     other
#     NA - The tweet is not a bullying trace and we didn't annotate its author role
# Emotion:
#
#     anger
#     embarrassment
#     empathy
#     fear
#     none
#     other
#     pride
#     relief
#     sadness
#     NA - The tweet is not a bullying trace and we didn't annotate its emotion
